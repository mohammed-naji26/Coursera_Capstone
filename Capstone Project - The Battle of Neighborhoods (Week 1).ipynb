# %% [markdown]
# ## <center> Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ### <center> By Mohammed Naji

# %% [markdown]
# #### Context
#
# Crime incident reports are provided by Boston Police Department (BPD) to document the initial details surrounding an incident to which BPD officers respond. This is a dataset containing records from the new crime incident report system, which includes a reduced set of fields focused on capturing the type of incident as well as when and where it occurred.
#
# #### Inspiration
#
# What types of crimes are most common?
# Where are different types of crimes most likely to occur?
# Does the frequency of crimes change over the day? Week? Year?

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/coursera-spatial-data-analysis/master/boston-crime%202.csv')
df.head(10)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0      I192082859           724                       Auto Theft
# 1      I192082751           724                       Auto Theft
# 2      I192082680           727                       Auto Theft
# 3      I192082577           724                       Auto Theft
# 4      I192079582           727                       Auto Theft
# 5      I192078648          3114             Investigate Property
# 6      I192078647          3115               Investigate Person
# 7      I192078645          3301                  Verbal Disputes
# 8      I192078645          1402                        Vandalism
# 9      I192078642          3820  Motor Vehicle Accident Response
#
#                           OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                                  AUTO THEFT      E18            519
# 1                                  AUTO THEFT      E18            493
# 2          AUTO THEFT - LEASED/RENTED VEHICLE      D14            794
# 3                                  AUTO THEFT       D4            130
# 4          AUTO THEFT - LEASED/RENTED VEHICLE      A15             47
# 5                        INVESTIGATE PROPERTY       B3            427
# 6                          INVESTIGATE PERSON       A1
# 7                              VERBAL DISPUTE       B3            450
# 8                                   VANDALISM       B3            450
# 9  M/V ACCIDENT INVOLVING PEDESTRIAN - INJURY       D4            269
#
#    SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0       NaN  2019-10-13 09:28:24  2019     10      Sunday     9    Part One
# 1       NaN  2019-10-12 20:11:26  2019     10    Saturday    20    Part One
# 2       NaN  2019-10-12 15:12:43  2019     10    Saturday    15    Part One
# 3       NaN  2019-10-12 04:41:52  2019     10    Saturday     4    Part One
# 4       NaN  2019-10-02 08:08:49  2019     10   Wednesday     8    Part One
# 5       NaN  2019-09-29 06:39:00  2019      9      Sunday     6  Part Three
# 6       NaN  2019-09-29 03:45:00  2019      9      Sunday     3  Part Three
# 7       NaN  2019-09-29 06:00:00  2019      9      Sunday     6  Part Three
# 8       NaN  2019-09-29 06:00:00  2019      9      Sunday     6    Part Two
# 9       NaN  2019-09-29 05:50:00  2019      9      Sunday     5  Part Three
#
#              STREET        Lat       Long                     Location  \
# 0        LINCOLN ST  42.259518 -71.121563  (42.25951765, -71.12156299)
# 1  METROPOLITAN AVE  42.262092 -71.116710  (42.26209214, -71.11670964)
# 2        ALLSTON ST  42.352375 -71.135096  (42.35237455, -71.13509584)
# 3   SAINT JAMES AVE  42.349476 -71.076402  (42.34947586, -71.07640150)
# 4         N MEAD ST  42.381846 -71.066551  (42.38184582, -71.06655134)
# 5        WILMORE ST  42.277964 -71.092463  (42.27796370, -71.09246318)
# 6         NASHUA ST  42.367690 -71.065863  (42.36769032, -71.06586347)
# 7      ASPINWALL RD  42.291816 -71.072441  (42.29181580, -71.07244098)
# 8      ASPINWALL RD  42.291816 -71.072441  (42.29181580, -71.07244098)
# 9         ALBANY ST  42.332419 -71.075013  (42.33241896, -71.07501315)
#
#          Date      Time
# 0  2019-10-13  09:28:24
# 1  2019-10-12  20:11:26
# 2  2019-10-12  15:12:43
# 3  2019-10-12  04:41:52
# 4  2019-10-02  08:08:49
# 5  2019-09-29  06:39:00
# 6  2019-09-29  03:45:00
# 7  2019-09-29  06:00:00
# 8  2019-09-29  06:00:00
# 9  2019-09-29  05:50:00
